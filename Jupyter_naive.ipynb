# %%
import pandas as pd
df = pd.read_csv("tree.csv")
df.head(50)
# Out:
#      1  very small   reforestation  good   sunny  very_small  A
# 0    2       small  urban planting  fair   rainy      _small  C
# 1    3       small    agroforestry  poor  cloudy  very_small  B
# 2    4      medium    agroforestry  good   sunny     _medium  A
# 3    5      medium  urban planting  fair   rainy      _small  B
# 4    6      medium   reforestation  good  cloudy      _small  A
# 5    7  very small    agroforestry  poor   sunny  very_small  B
# 6    8       small    agroforestry  fair   rainy      _small  D
# 7    9       large   reforestation  good  cloudy     _medium  B
# 8   10  very large  urban planting  fair   sunny  very_large  E
# 9   11       large   reforestation  poor   sunny      _large  C
# 10  12      medium  urban planting  good   rainy     _medium  B
# 11  13       small    agroforestry  fair  cloudy      _small  A
# 12  14  very small  urban planting  good   sunny  very_small  D
# 13  15  very large   reforestation  fair   rainy      _large  E
# ...

# %%
target =df.Survived
inputs =
